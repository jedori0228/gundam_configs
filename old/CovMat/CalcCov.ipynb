# %%
import json
import BinParser
import uproot
import pickle
import numpy as np
import pandas as pd
import icarusplot
import os

# %%
WD = '/Users/jskim/Documents/Neutrino/ICARUS/GUNDAM-1.9.X/work/CovMat'

# %%
PlotDir = f'{WD}/plots'
os.system('mkdir -p '+PlotDir)
# Out:
# 0

# %%
OutDir = f'{WD}/outputs'
os.system('mkdir -p '+OutDir)
# Out:
# 0

# %%
# ConfigFileName = 'config_G4PipFate.json'
# ConfigFileName = 'config_G4PimFate.json'
# ConfigFileName = 'config_G4ProtonFate.json'


# ConfigFileName = 'config_GENIE_fsi_N_TrueMuonCos.json'
# ConfigFileName = 'config_GENIE_fsi_pi_TrueMuonCos.json'

# ConfigFileName = 'config_GENIE_fsi_N_TrueMuonProtonCos.json'
# ConfigFileName = 'config_GENIE_fsi_pi_TrueMuonProtonCos.json'

# ConfigFileName = 'config_GENIE_fsi_pi_TrueMuonProtonCos_vs_TrueMuonCos.json'
ConfigFileName = 'config_GENIE_fsi_N_TrueMuonProtonCos_vs_TrueMuonCos.json'


# ConfigFileName = 'config_GENIE_fsi_N_TruedeltaPT.json'
# ConfigFileName = 'config_GENIE_fsi_pi_TruedeltaPT.json'

# ConfigFileName = 'config_GENIE_fsi_pi_TruedeltaalphaT.json'
# ConfigFileName = 'config_GENIE_fsi_N_TruedeltaalphaT.json'

# ConfigFileName = 'config_GENIE_fsi_pi_TruedeltaalphaT_vs_TruedeltaPT.json'
# ConfigFileName = 'config_GENIE_fsi_N_TruedeltaalphaT_vs_TruedeltaPT.json'

f_json = open(ConfigFileName)
json_config = json.load(f_json)

# %%
json_MainTree = json_config['MainTree']

# Input file
InputFileName = json_MainTree['FilePath']
TreeKey = json_MainTree['TreeKey']
print('- InputFileName: %s'%(InputFileName))
print('- TreeKey: %s'%(TreeKey))

with open(InputFileName, 'rb') as f:
    data_dict = pickle.load(f)

df = data_dict[TreeKey]

# if '/' in TreeKey:

#     with open(InputFileName, 'rb') as f:
#         data_dict = pickle.load(f)

#     del data_dict['TrueDFs']

#     df = data_dict['RecoDFs']['BeamMC']

#     # clean up
#     data_dict_keysList = list(data_dict['RecoDFs'].keys())
#     for key in data_dict_keysList:
#         if key != 'BeamMC':
#             del data_dict['RecoDFs'][key]

# else:

#     with open(InputFileName, 'rb') as f:
#         data_dict = pickle.load(f)

#     df = data_dict[TreeKey]
# Out:
# - InputFileName: /Users/jskim/Documents/Neutrino/ICARUS/GUNDAM-1.9.X/work/CovMat/inputfiles/dfs_MakeFSICovTree.pkl
# - TreeKey: df

# %%
# Cut and Sample selection

SelectionCutExpr = json_config['SelectionCutExpr']
SampleSelectionExpr = json_config['SampleSelectionExpr']
SampleWeightExpr = json_config['SampleWeightExpr']
print('- Selection cut: %s'%(SelectionCutExpr))
print('- Sample selection: %s'%(SampleSelectionExpr))
print('- Sample weight: %s'%(SampleWeightExpr))
# Out:
# - Selection cut: CutType>=0
# - Sample selection: CutType>=0
# - Sample weight: FluxWeightWithG3Chase * SPPCVCorrection

# %%
# Evaluate the weight expr
df = df.eval('FinalWeight = %s'%(SampleWeightExpr))

# %%
# Binning
BinningFile = json_config['BinningFile']
print('- Binning from %s:'%(BinningFile))
bin_parser = BinParser.BinParser(BinningFile)
NBins = len(bin_parser.CutExprs)
for i_Cut, CutExpr in enumerate(bin_parser.CutExprs):
    print('bin %d: '%(i_Cut), CutExpr)
# Out:
# - Binning from /Users/jskim/Documents/Neutrino/ICARUS/GUNDAM-1.9.X/work/binnings/Make2DBinning/binning_TrueMuonProtonCos_vs_TrueMuonCos.txt:
# [BinParser][__init__] Reading binning info from /Users/jskim/Documents/Neutrino/ICARUS/GUNDAM-1.9.X/work/binnings/Make2DBinning/binning_TrueMuonProtonCos_vs_TrueMuonCos.txt
# Variable name: TrueMuonProtonCos, Type: float
# Variable name: TrueMuonCos, Type: float
# bin 0:  TrueMuonProtonCos>=-1.0000 & TrueMuonProtonCos<-0.5806 & TrueMuonCos>=-1.0000 & TrueMuonCos<0.1516
# bin 1:  TrueMuonProtonCos>=-1.0000 & TrueMuonProtonCos<-0.5806 & TrueMuonCos>=0.1516 & TrueMuonCos<0.5282
# bin 2:  TrueMuonProtonCos>=-1.0000 & TrueMuonProtonCos<-0.5806 & TrueMuonCos>=0.5282 & TrueMuonCos<0.7320
# bin 3:  TrueMuonProtonCos>=-1.0000 & TrueMuonProtonCos<-0.5806 & TrueMuonCos>=0.7320 & TrueMuonCos<0.8446
# bin 4:  TrueMuonProtonCos>=-1.0000 & TrueMuonProtonCos<-0.5806 & TrueMuonCos>=0.8446 & TrueMuonCos<0.9122
# bin 5:  TrueMuonProtonCos>=-1.0000 & TrueMuonProtonCos<-0.5806 & TrueMuonCos>=0.9122 & TrueMuonCos<0.9518
# bin 6:  TrueMuonProtonCos>=-1.0000 & TrueMuonProtonCos<-0.5806 & TrueMuonCos>=0.9518 & TrueMuonCos<0.9780
# bin 7:  TrueMuonProtonCos>=-1.0000 & TrueMuonProtonCos<-0.5806 & TrueMuonCos>=0.9780 & TrueMuonCos<1.0000
# bin 8:  TrueMuonProtonCos>=-0.5806 & TrueMuonProtonCos<-0.3628 & TrueMuonCos>=-1.0000 & TrueMuonCos<0.1516
# bin 9:  TrueMuonProtonCos>=-0.5806 & TrueMuonProtonCos<-0.3628 & TrueMuonCos>=0.1516 & TrueMuonCos<0.5282
# bin 10:  TrueMuonProtonCos>=-0.5806 & TrueMuonProtonCos<-0.3628 & TrueMuonCos>=0.5282 & TrueMuonCos<0.7320
# bin 11:  TrueMuonProtonCos>=-0.5806 & TrueMuonProtonCos<-0.3628 & TrueMuonCos>=0.7320 & TrueMuonCos<0.8446
# bin 12:  TrueMuonProtonCos>=-0.5806 & TrueMuonProtonCos<-0.3628 & TrueMuonCos>=0.8446 & TrueMuonCos<0.9122
# bin 13:  TrueMuonProtonCos>=-0.5806 & TrueMuonProtonCos<-0.3628 & TrueMuonCos>=0.9122 & TrueMuonCos<0.9518
# bin 14:  TrueMuonProtonCos>=-0.5806 & TrueMuonProtonCos<-0.3628 & TrueMuonCos>=0.9518 & TrueMuonCos<0.9780
# bin 15:  TrueMuonProtonCos>=-0.5806 & TrueMuonProtonCos<-0.3628 & TrueMuonCos>=0.9780 & TrueMuonCos<1.0000
# bin 16:  TrueMuonProtonCos>=-0.3628 & TrueMuonProtonCos<-0.1926 & TrueMuonCos>=-1.0000 & TrueMuonCos<0.1516
# bin 17:  TrueMuonProtonCos>=-0.3628 & TrueMuonProtonCos<-0.1926 & TrueMuonCos>=0.1516 & TrueMuonCos<0.5282
# bin 18:  TrueMuonProtonCos>=-0.3628 & TrueMuonProtonCos<-0.1926 & TrueMuonCos>=0.5282 & TrueMuonCos<0.7320
# bin 19:  TrueMuonProtonCos>=-0.3628 & TrueMuonProtonCos<-0.1926 & TrueMuonCos>=0.7320 & TrueMuonCos<0.8446
# bin 20:  TrueMuonProtonCos>=-0.3628 & TrueMuonProtonCos<-0.1926 & TrueMuonCos>=0.8446 & TrueMuonCos<0.9122
# bin 21:  TrueMuonProtonCos>=-0.3628 & TrueMuonProtonCos<-0.1926 & TrueMuonCos>=0.9122 & TrueMuonCos<0.9518
# bin 22:  TrueMuonProtonCos>=-0.3628 & TrueMuonProtonCos<-0.1926 & TrueMuonCos>=0.9518 & TrueMuonCos<0.9780
# bin 23:  TrueMuonProtonCos>=-0.3628 & TrueMuonProtonCos<-0.1926 & TrueMuonCos>=0.9780 & TrueMuonCos<1.0000
# bin 24:  TrueMuonProtonCos>=-0.1926 & TrueMuonProtonCos<-0.0424 & TrueMuonCos>=-1.0000 & TrueMuonCos<0.1516
# bin 25:  TrueMuonProtonCos>=-0.1926 & TrueMuonProtonCos<-0.0424 & TrueMuonCos>=0.1516 & TrueMuonCos<0.5282
# bin 26:  TrueMuonProtonCos>=-0.1926 & TrueMuonProtonCos<-0.0424 & TrueMuonCos>=0.5282 & TrueMuonCos<0.7320
# bin 27:  TrueMuonProtonCos>=-0.1926 & TrueMuonProtonCos<-0.0424 & TrueMuonCos>=0.7320 & TrueMuonCos<0.8446
# bin 28:  TrueMuonProtonCos>=-0.1926 & TrueMuonProtonCos<-0.0424 & TrueMuonCos>=0.8446 & TrueMuonCos<0.9122
# bin 29:  TrueMuonProtonCos>=-0.1926 & TrueMuonProtonCos<-0.0424 & TrueMuonCos>=0.9122 & TrueMuonCos<0.9518
# bin 30:  TrueMuonProtonCos>=-0.1926 & TrueMuonProtonCos<-0.0424 & TrueMuonCos>=0.9518 & TrueMuonCos<0.9780
# bin 31:  TrueMuonProtonCos>=-0.1926 & TrueMuonProtonCos<-0.0424 & TrueMuonCos>=0.9780 & TrueMuonCos<1.0000
# bin 32:  TrueMuonProtonCos>=-0.0424 & TrueMuonProtonCos<0.0814 & TrueMuonCos>=-1.0000 & TrueMuonCos<0.1516
# bin 33:  TrueMuonProtonCos>=-0.0424 & TrueMuonProtonCos<0.0814 & TrueMuonCos>=0.1516 & TrueMuonCos<0.5282
# bin 34:  TrueMuonProtonCos>=-0.0424 & TrueMuonProtonCos<0.0814 & TrueMuonCos>=0.5282 & TrueMuonCos<0.7320
# bin 35:  TrueMuonProtonCos>=-0.0424 & TrueMuonProtonCos<0.0814 & TrueMuonCos>=0.7320 & TrueMuonCos<0.8446
# bin 36:  TrueMuonProtonCos>=-0.0424 & TrueMuonProtonCos<0.0814 & TrueMuonCos>=0.8446 & TrueMuonCos<0.9122
# bin 37:  TrueMuonProtonCos>=-0.0424 & TrueMuonProtonCos<0.0814 & TrueMuonCos>=0.9122 & TrueMuonCos<0.9518
# bin 38:  TrueMuonProtonCos>=-0.0424 & TrueMuonProtonCos<0.0814 & TrueMuonCos>=0.9518 & TrueMuonCos<0.9780
# bin 39:  TrueMuonProtonCos>=-0.0424 & TrueMuonProtonCos<0.0814 & TrueMuonCos>=0.9780 & TrueMuonCos<1.0000
# bin 40:  TrueMuonProtonCos>=0.0814 & TrueMuonProtonCos<0.2018 & TrueMuonCos>=-1.0000 & TrueMuonCos<0.1516
# bin 41:  TrueMuonProtonCos>=0.0814 & TrueMuonProtonCos<0.2018 & TrueMuonCos>=0.1516 & TrueMuonCos<0.5282
# bin 42:  TrueMuonProtonCos>=0.0814 & TrueMuonProtonCos<0.2018 & TrueMuonCos>=0.5282 & TrueMuonCos<0.7320
# bin 43:  TrueMuonProtonCos>=0.0814 & TrueMuonProtonCos<0.2018 & TrueMuonCos>=0.7320 & TrueMuonCos<0.8446
# bin 44:  TrueMuonProtonCos>=0.0814 & TrueMuonProtonCos<0.2018 & TrueMuonCos>=0.8446 & TrueMuonCos<0.9122
# bin 45:  TrueMuonProtonCos>=0.0814 & TrueMuonProtonCos<0.2018 & TrueMuonCos>=0.9122 & TrueMuonCos<0.9518
# bin 46:  TrueMuonProtonCos>=0.0814 & TrueMuonProtonCos<0.2018 & TrueMuonCos>=0.9518 & TrueMuonCos<0.9780
# bin 47:  TrueMuonProtonCos>=0.0814 & TrueMuonProtonCos<0.2018 & TrueMuonCos>=0.9780 & TrueMuonCos<1.0000
# bin 48:  TrueMuonProtonCos>=0.2018 & TrueMuonProtonCos<0.3286 & TrueMuonCos>=-1.0000 & TrueMuonCos<0.1516
# bin 49:  TrueMuonProtonCos>=0.2018 & TrueMuonProtonCos<0.3286 & TrueMuonCos>=0.1516 & TrueMuonCos<0.5282
# bin 50:  TrueMuonProtonCos>=0.2018 & TrueMuonProtonCos<0.3286 & TrueMuonCos>=0.5282 & TrueMuonCos<0.7320
# bin 51:  TrueMuonProtonCos>=0.2018 & TrueMuonProtonCos<0.3286 & TrueMuonCos>=0.7320 & TrueMuonCos<0.8446
# bin 52:  TrueMuonProtonCos>=0.2018 & TrueMuonProtonCos<0.3286 & TrueMuonCos>=0.8446 & TrueMuonCos<0.9122
# bin 53:  TrueMuonProtonCos>=0.2018 & TrueMuonProtonCos<0.3286 & TrueMuonCos>=0.9122 & TrueMuonCos<0.9518
# bin 54:  TrueMuonProtonCos>=0.2018 & TrueMuonProtonCos<0.3286 & TrueMuonCos>=0.9518 & TrueMuonCos<0.9780
# bin 55:  TrueMuonProtonCos>=0.2018 & TrueMuonProtonCos<0.3286 & TrueMuonCos>=0.9780 & TrueMuonCos<1.0000
# bin 56:  TrueMuonProtonCos>=0.3286 & TrueMuonProtonCos<0.4878 & TrueMuonCos>=-1.0000 & TrueMuonCos<0.1516
# bin 57:  TrueMuonProtonCos>=0.3286 & TrueMuonProtonCos<0.4878 & TrueMuonCos>=0.1516 & TrueMuonCos<0.5282
# bin 58:  TrueMuonProtonCos>=0.3286 & TrueMuonProtonCos<0.4878 & TrueMuonCos>=0.5282 & TrueMuonCos<0.7320
# bin 59:  TrueMuonProtonCos>=0.3286 & TrueMuonProtonCos<0.4878 & TrueMuonCos>=0.7320 & TrueMuonCos<0.8446
# bin 60:  TrueMuonProtonCos>=0.3286 & TrueMuonProtonCos<0.4878 & TrueMuonCos>=0.8446 & TrueMuonCos<0.9122
# bin 61:  TrueMuonProtonCos>=0.3286 & TrueMuonProtonCos<0.4878 & TrueMuonCos>=0.9122 & TrueMuonCos<0.9518
# bin 62:  TrueMuonProtonCos>=0.3286 & TrueMuonProtonCos<0.4878 & TrueMuonCos>=0.9518 & TrueMuonCos<0.9780
# bin 63:  TrueMuonProtonCos>=0.3286 & TrueMuonProtonCos<0.4878 & TrueMuonCos>=0.9780 & TrueMuonCos<1.0000
# bin 64:  TrueMuonProtonCos>=0.4878 & TrueMuonProtonCos<0.7016 & TrueMuonCos>=-1.0000 & TrueMuonCos<0.1516
# bin 65:  TrueMuonProtonCos>=0.4878 & TrueMuonProtonCos<0.7016 & TrueMuonCos>=0.1516 & TrueMuonCos<0.5282
# bin 66:  TrueMuonProtonCos>=0.4878 & TrueMuonProtonCos<0.7016 & TrueMuonCos>=0.5282 & TrueMuonCos<0.7320
# bin 67:  TrueMuonProtonCos>=0.4878 & TrueMuonProtonCos<0.7016 & TrueMuonCos>=0.7320 & TrueMuonCos<0.8446
# bin 68:  TrueMuonProtonCos>=0.4878 & TrueMuonProtonCos<0.7016 & TrueMuonCos>=0.8446 & TrueMuonCos<0.9122
# bin 69:  TrueMuonProtonCos>=0.4878 & TrueMuonProtonCos<0.7016 & TrueMuonCos>=0.9122 & TrueMuonCos<0.9518
# bin 70:  TrueMuonProtonCos>=0.4878 & TrueMuonProtonCos<0.7016 & TrueMuonCos>=0.9518 & TrueMuonCos<0.9780
# bin 71:  TrueMuonProtonCos>=0.4878 & TrueMuonProtonCos<0.7016 & TrueMuonCos>=0.9780 & TrueMuonCos<1.0000
# bin 72:  TrueMuonProtonCos>=0.7016 & TrueMuonProtonCos<1.0000 & TrueMuonCos>=-1.0000 & TrueMuonCos<0.1516
# bin 73:  TrueMuonProtonCos>=0.7016 & TrueMuonProtonCos<1.0000 & TrueMuonCos>=0.1516 & TrueMuonCos<0.5282
# bin 74:  TrueMuonProtonCos>=0.7016 & TrueMuonProtonCos<1.0000 & TrueMuonCos>=0.5282 & TrueMuonCos<0.7320
# bin 75:  TrueMuonProtonCos>=0.7016 & TrueMuonProtonCos<1.0000 & TrueMuonCos>=0.7320 & TrueMuonCos<0.8446
# bin 76:  TrueMuonProtonCos>=0.7016 & TrueMuonProtonCos<1.0000 & TrueMuonCos>=0.8446 & TrueMuonCos<0.9122
# bin 77:  TrueMuonProtonCos>=0.7016 & TrueMuonProtonCos<1.0000 & TrueMuonCos>=0.9122 & TrueMuonCos<0.9518
# bin 78:  TrueMuonProtonCos>=0.7016 & TrueMuonProtonCos<1.0000 & TrueMuonCos>=0.9518 & TrueMuonCos<0.9780
# bin 79:  TrueMuonProtonCos>=0.7016 & TrueMuonProtonCos<1.0000 & TrueMuonCos>=0.9780 & TrueMuonCos<1.0000

# %%
# Get Nominal histogram
h_Nom = np.zeros(NBins)
for i_Cut, CutExpr in enumerate(bin_parser.CutExprs):
    this_CutExpr = '(%s) & (%s) & (%s)'%(SelectionCutExpr, SampleSelectionExpr, CutExpr)
    this_WeightExpr = 'FinalWeight'

    this_bincontent = np.sum( df.query(this_CutExpr)[this_WeightExpr]  )

    h_Nom[i_Cut] = this_bincontent
print(h_Nom)
# Out:
# [28616.68353587  5967.20227773  3820.66765129  3020.10705643
#   2813.83645721  2503.32033585  2411.56741056  3175.1301091
#  12673.64966814  6331.41205408  3541.48794963  2601.44881962
#   2270.70668491  2028.23367667  1960.47633348  2368.92152805
#   7311.6172851   7205.87424943  4362.84500569  2876.17506367
#   2531.49562971  2107.36960566  2005.66951831  2463.89000653
#   4491.86502327  6711.75291106  5280.52493538  3885.30269812
#   3113.84328882  2531.89249327  2416.05224861  2660.1165541
#   2840.35362458  5034.33843225  5217.14769061  4243.65469864
#   3679.98058094  3052.36042025  2762.7729719   2859.44367516
#   2115.09727352  4186.64022598  5270.57155693  5019.2649502
#   4594.33239612  3962.24206808  3417.82047444  3379.03690163
#   1724.19801128  3688.77940026  5069.51485537  5438.70952542
#   5484.98917052  4737.92934615  4158.09834668  4197.81823783
#   1756.21677439  3533.08913633  5911.57963761  6391.032811
#   6789.6520548   6087.21123369  5606.74211211  5881.89242048
#   1748.80219799  3251.40298194  6240.06943497  8086.57969198
#   9003.5369287   8021.07527093  7871.10535414  8882.42549288
#   1655.94272008  2709.06573474  4834.46337942  7571.32754786
#  10007.09429278 11038.11105027 12210.37866302 15655.01302205]

# %%
JobName = json_config['JobName']
DialName = json_config['DialName']
NUniv = json_config['NUniv']

print('JobName = ', JobName)
print('DialName = ', DialName)
print('NUniv = ', NUniv)

RW_ndarray = np.array(df[DialName].tolist())

h_Univs = np.zeros((NUniv, NBins))

for i_Cut, CutExpr in enumerate(bin_parser.CutExprs):
    this_CutExpr = '(%s) & (%s) & (%s)'%(SelectionCutExpr, SampleSelectionExpr, CutExpr)
    this_WeightExpr = 'FinalWeight'

    df_Selected = df.query(this_CutExpr)
    RW_ndarray = np.array(df_Selected[DialName].tolist())

    for Univ in range(NUniv):
        this_bincontent = np.sum( df_Selected[this_WeightExpr] *  RW_ndarray[:, Univ] )
        h_Univs[Univ][i_Cut] = this_bincontent

    del df_Selected
# Out:
# JobName =  GENIE_fsi_N_TrueMuonProtonCos_vs_TrueMuonCos
# DialName =  FSI_N_VariationResponse
# NUniv =  100

# %%
h_Univs[0]
# Out:
# array([28763.58819954,  5911.88539574,  3746.25740785,  2974.72514201,
#         2754.29267719,  2445.88105757,  2384.56634228,  3142.33689915,
#        12734.48186861,  6367.05155536,  3522.29586919,  2563.72916078,
#         2255.1717509 ,  2008.53506155,  1907.30140671,  2334.60345196,
#         7336.07442564,  7291.00976333,  4368.50553597,  2869.32256698,
#         2522.74128228,  2063.06092885,  1991.67160944,  2444.45427554,
#         4437.42708283,  6781.90834143,  5294.00539277,  3909.15204843,
#         3088.93219018,  2538.00105725,  2438.86501057,  2646.67436891,
#         2824.45283134,  5110.98784429,  5305.93490789,  4281.56149289,
#         3694.73806278,  3102.59395911,  2808.62575889,  2902.55243756,
#         2097.50125838,  4185.38696411,  5300.27788475,  5101.52665201,
#         4630.3487817 ,  3987.33364205,  3440.47410062,  3388.47053123,
#         1704.55070905,  3705.58035354,  5087.59318928,  5530.25106122,
#         5556.55177487,  4795.97762246,  4224.30529758,  4224.13150905,
#         1738.40562748,  3473.61145445,  5985.98121611,  6498.73637789,
#         6865.49183207,  6198.44947335,  5689.15688731,  5989.389605  ,
#         1711.73149346,  3228.38290748,  6264.99869577,  8163.69829251,
#         9056.69211685,  8072.38759646,  7949.89017969,  9073.31827659,
#         1635.86027555,  2649.69539312,  4782.44828256,  7515.43091938,
#        10035.74696409, 11090.67950435, 12298.29940736, 15913.25116444])

# %%
h_Mean = np.mean(h_Univs, axis=0)

# %%
h_Mean
# Out:
# array([28695.71593342,  5932.74932708,  3784.07879537,  2989.95646761,
#         2779.14443339,  2474.4284963 ,  2388.40661613,  3142.29542074,
#        12700.9056386 ,  6334.22192521,  3533.01239178,  2584.47358405,
#         2255.13218679,  2008.99118221,  1945.27297829,  2351.84328986,
#         7319.93783027,  7224.24625924,  4362.46763974,  2869.63432319,
#         2521.29866447,  2097.60872136,  1994.81693725,  2450.75555122,
#         4485.95862455,  6733.423606  ,  5291.00193048,  3883.8945055 ,
#         3112.69167213,  2526.58202571,  2405.97459115,  2648.66760959,
#         2827.89803545,  5048.61239741,  5231.89795989,  4253.36520386,
#         3680.44777701,  3051.24920994,  2760.82283723,  2853.57518709,
#         2101.12793729,  4193.36017443,  5290.54123497,  5032.56627263,
#         4605.77786976,  3966.69241585,  3420.91858268,  3374.28080776,
#         1709.48497662,  3689.45216933,  5084.54543249,  5451.44129447,
#         5498.31788125,  4745.09201744,  4161.6107313 ,  4195.79472475,
#         1737.2199767 ,  3524.3400882 ,  5920.71667854,  6405.07314669,
#         6806.71470299,  6096.03440655,  5611.99609895,  5882.94950456,
#         1728.41989698,  3235.52760939,  6234.65760755,  8087.66768659,
#         9012.15046368,  8029.80528619,  7874.07973788,  8890.38274856,
#         1634.82912675,  2679.38557146,  4804.85032175,  7545.01048698,
#         9995.45809878, 11031.18510516, 12208.80693097, 15675.18001423])

# %%
h_Cov = np.zeros((NBins, NBins))
for i in range(NBins):
    for j in range(NBins):
        h_Cov[i][j] = np.sum((h_Univs[:, i] - h_Mean[i]) * (h_Univs[:, j] - h_Mean[j])) / (NUniv - 1) / h_Mean[i] / h_Mean[j]

h_Corr = np.zeros((NBins, NBins))
for i in range(NBins):
    for j in range(NBins):
        h_Corr[i][j] = h_Cov[i][j] / np.sqrt( h_Cov[i, i] ) / np.sqrt( h_Cov[j, j] )

# %%
import ROOT

OutputFileName = json_config['OutputFileName']
f_out = ROOT.TFile(f'{OutDir}/{OutputFileName}', 'RECREATE')

h_Cov_TMat = ROOT.TMatrixDSym(NBins)
for i in range(NBins):
    for j in range(NBins):
        h_Cov_TMat[i][j] = h_Cov[i, j]

h_Corr_TMat = ROOT.TMatrixDSym(NBins)
for i in range(NBins):
    for j in range(NBins):
        h_Corr_TMat[i][j] = h_Corr[i, j]

f_out.mkdir(JobName)
f_out.cd(JobName)
h_Cov_TMat.Write('%s_covariance'%(JobName))
h_Corr_TMat.Write('%s_correlation'%(JobName))
f_out.cd()
f_out.Close()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,10))

# Plot the heatmap
cax = ax.matshow(h_Cov, cmap='coolwarm')

# Add colorbar
plt.colorbar(cax)

cax_lims = cax.get_clim()
cax_max = max( abs(cax_lims[0]), abs(cax_lims[1]) )
cax.set_clim(-1.*cax_max, +1*cax_max)
cax_use_red = 0.75*cax_max

# Add text annotations for each cell
if h_Cov.shape[0]<10:
    for i in range(h_Cov.shape[0]):
        for j in range(h_Cov.shape[1]):
            if h_Cov[i, j]>cax_use_red:
                ax.text(j, i, '%1.1e'%(h_Cov[i, j]), ha='center', va='center', color='white')
            else:
                ax.text(j, i, '%1.1e'%(h_Cov[i, j]), ha='center', va='center', color='k')
# Set labels
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_title('Covariance Matrix: %s'%(JobName), fontsize=30)

# Show plot
plt.show()

fig.savefig(f'{PlotDir}/CovMat_%s.pdf'%(JobName), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,10))

# Plot the heatmap
cax = ax.matshow(h_Corr, cmap='coolwarm')

# Add colorbar
plt.colorbar(cax)
cax.set_clim(-1, +1)
cax_use_red = 0.75*cax_max

# Add text annotations for each cell
if h_Corr.shape[0]<10:
    for i in range(h_Corr.shape[0]):
        for j in range(h_Corr.shape[1]):
            if abs(h_Corr[i, j])>cax_use_red:
                ax.text(j, i, '%1.3f'%(h_Corr[i, j]), ha='center', va='center', color='white')
            else:
                ax.text(j, i, '%1.3f'%(h_Corr[i, j]), ha='center', va='center', color='k')
# Set labels
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_title('Correlation Matrix: %s'%(JobName), fontsize=30)


# Show plot
plt.show()

fig.savefig(f'{PlotDir}/CorrMat_%s.pdf'%(JobName), bbox_inches='tight')
